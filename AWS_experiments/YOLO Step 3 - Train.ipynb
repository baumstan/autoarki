# %% [markdown]
# # YOLO Step 3

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import boto3
import io
import pandas as pd
import json
import s3fs
import os

# %%
my_bucket = 'autoarki-ground-truth-labeling'
client = boto3.client('s3')
response = client.list_objects_v2(Bucket=my_bucket)
session = boto3.Session(aws_access_key_id = os.getenv('AWSAccessKeyId'), 
                        aws_secret_access_key = os.getenv('AWS_SECRET_ACCESS_KEY'))

# %%
# change directory and copy files locally -- only do once
import os
# os.chdir("/home/ec2-user/AutoArki/yolov5/yolov5/training_data")
# !aws s3 cp s3://autoarki-ground-truth-labeling/training_data . --recursive
# os.chdir("/home/ec2-user/AutoArki/yolov5/yolov5/test_data")
# !aws s3 cp s3://autoarki-ground-truth-labeling/test_data . --recursive

# %%
train_dir = "training_data/"
test_dir = "test_data/"

# %% [markdown]
# # Learning

# %% [markdown]
# use smallest YOLO model to start yolov5s.pt

# %%
import torch
import torchvision

# %%
os.chdir("/home/ec2-user/AutoArki/yolov5/yolov5/")
# !pip install -r requirements.txt  # install

# %%
# !python train.py\
    --data custom_dataset.yaml \
    --epochs 30 \
    --project custom_yolov5 \
    --bbox_interval 1 \
    --save-period 1 \
    --weights yolov5s.pt
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=custom_dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=custom_yolov5, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-10-gc2403eb torch 1.10.2+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir custom_yolov5', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 22.3MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7022326 parameters, 7022326 gradients, 15.8 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# train: Scanning '/home/ec2-user/AutoArki/yolov5/yolov5/training_data' images and
# train: New cache created: /home/ec2-user/AutoArki/yolov5/yolov5/training_data.cache
# val: Scanning '/home/ec2-user/AutoArki/yolov5/yolov5/test_data' images and label
# val: New cache created: /home/ec2-user/AutoArki/yolov5/yolov5/test_data.cache
# Plotting labels to custom_yolov5/exp5/labels.jpg...
#
# AutoAnchor: 5.40 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to custom_yolov5/exp5
# Starting training for 30 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/29     3.26G    0.1231    0.0242         0        11       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100   0.000323       0.02   0.000114   2.26e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/29     4.31G    0.1126   0.01655         0         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100    0.00119       0.02   0.000101   2.12e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/29     4.31G    0.1047   0.01193         0        12       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100   0.000556       0.09    0.00027   5.47e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/29     4.31G   0.09776  0.009787         0         5       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100    0.00138       0.01   0.000603   0.000139
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/29     4.31G   0.09544   0.01001         0         6       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100     0.0332       0.06    0.00836    0.00131
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/29     4.31G   0.09345   0.01024         0         5       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.024       0.04    0.00388   0.000748
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/29     4.31G   0.08763  0.008607         0        14       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100     0.0351       0.04    0.00444    0.00113
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/29     4.31G   0.08214   0.01001         0        18       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100     0.0161       0.37     0.0127    0.00269
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/29     4.31G   0.07789  0.009669         0        10       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.219       0.04     0.0308    0.00524
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/29     4.31G   0.07282   0.01148         0        11       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.052       0.45     0.0421    0.00788
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/29     4.31G   0.07148  0.009503         0        10       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100       0.21       0.08     0.0615     0.0117
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/29     4.31G   0.07243  0.009613         0        11       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100     0.0492       0.42     0.0416    0.00973
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/29     4.31G   0.06569   0.01049         0         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100     0.0752       0.13     0.0296    0.00593
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/29     4.31G    0.0681  0.009753         0         8       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.122       0.27     0.0677     0.0176
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/29     4.31G   0.06767  0.009671         0        10       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.135       0.17     0.0625     0.0142
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/29     4.31G   0.06144   0.01008         0        11       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.179       0.37      0.123     0.0315
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/29     4.31G   0.06438  0.009883         0        11       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.405       0.25      0.226     0.0554
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/29     4.31G    0.0618  0.009178         0        13       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.244        0.5      0.218     0.0555
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/29     4.31G   0.06067  0.008716         0         5       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.233      0.291      0.132     0.0315
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/29     4.31G   0.05872  0.009151         0        11       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100       0.15       0.22     0.0702      0.021
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      20/29     4.31G   0.05964  0.009365         0        11       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.209       0.32       0.16     0.0455
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      21/29     4.31G   0.06024  0.009059         0         5       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.332       0.31      0.221     0.0668
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      22/29     4.31G   0.05798   0.01019         0        10       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.405       0.33      0.281     0.0849
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      23/29     4.31G   0.05966   0.01013         0        12       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.448       0.36      0.334     0.0981
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      24/29     4.31G   0.05533   0.01057         0         6       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.348       0.57      0.394      0.139
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      25/29     4.31G   0.05391  0.009499         0        14       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.376       0.41      0.352      0.124
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      26/29     4.31G    0.0586  0.009063         0         3       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.514       0.34      0.357      0.124
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      27/29     4.31G   0.04949   0.01046         0         8       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100        0.5       0.35      0.354      0.117
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      28/29     4.31G   0.05044  0.008097         0         8       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.552       0.39       0.38      0.106
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      29/29     4.31G   0.05456  0.009879         0         6       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100       0.52       0.43      0.409      0.123
#
# 30 epochs completed in 0.041 hours.
# Optimizer stripped from custom_yolov5/exp5/weights/last.pt, 14.5MB
# Optimizer stripped from custom_yolov5/exp5/weights/best.pt, 14.5MB
#
# Validating custom_yolov5/exp5/weights/best.pt...
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         63        100      0.356      0.579      0.393      0.137
# Results saved to custom_yolov5/exp5

# %%
#https://aws.amazon.com/blogs/machine-learning/announcing-the-amazon-s3-plugin-for-pytorch/
#from awsio.python.lib.io.s3.s3dataset import S3IterableDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 #https://aws.amazon.com/blogs/machine-learning/announcing-the-amazon-s3-plugin-for-pytorch/
# ----> 2 from awsio.python.lib.io.s3.s3dataset import S3IterableDataset
#
# ModuleNotFoundError: No module named 'awsio'

# %%
# !aws cp custom_yolov5/ s3://autoarki-ground-truth-labeling/yolo5-output/ --recursive
